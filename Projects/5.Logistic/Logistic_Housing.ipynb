# %%
import numpy as nm
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
#Linear

# %%
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Lab5/brooklyn_listings.csv')
df
# Out:
#        Unnamed: 0      price  bedrooms  bathrooms    sqft neighborhood  \
# 0               1  4100000.0         4          5  2940.0   Park Slope
# 1               2  1020000.0         3          1     NaN   Park Slope
# 2               3    45000.0         0          1     NaN   Park Slope
# 3               4    45000.0         0          1     NaN   Park Slope
# 4               5   908000.0         0          1  1066.0   Park Slope
# ...           ...        ...       ...        ...     ...          ...
# 14728       14620   630000.0         0          1  1492.0      Wingate
# 14729       14720   998000.0         4          2  1584.0      Wingate
# 14730       14820   830000.0         0          1   564.0      Wingate
# 14731       14920   240000.0         0          1     NaN      Wingate
# 14732       15020   629000.0         3          2  1470.0      Wingate
#
#        status                                    address
# 0        sold            336A 4th St, Brooklyn, NY 11215
# ...

# %%
df = df.drop(columns=['address'])

# %%
# prompt: eliminate unnamed feature

df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df
# Out:
#            price  bedrooms  bathrooms    sqft neighborhood  status
# 0      4100000.0         4          5  2940.0   Park Slope    sold
# 1      1020000.0         3          1     NaN   Park Slope    sold
# 2        45000.0         0          1     NaN   Park Slope    sold
# 3        45000.0         0          1     NaN   Park Slope    sold
# 4       908000.0         0          1  1066.0   Park Slope    sold
# ...          ...       ...        ...     ...          ...     ...
# 14728   630000.0         0          1  1492.0      Wingate  listed
# 14729   998000.0         4          2  1584.0      Wingate  listed
# 14730   830000.0         0          1   564.0      Wingate  listed
# 14731   240000.0         0          1     NaN      Wingate  listed
# 14732   629000.0         3          2  1470.0      Wingate  listed
#
# [14733 rows x 6 columns]

# %%
# eliminate the data where null value in sqft feature
df = df.dropna(subset=['sqft'])
df
# Out:
#            price  bedrooms  bathrooms    sqft neighborhood  status
# 0      4100000.0         4          5  2940.0   Park Slope    sold
# 4       908000.0         0          1  1066.0   Park Slope    sold
# 6      2600000.0         5          4  3600.0   Park Slope    sold
# 7      4050000.0         4          4  3600.0   Park Slope    sold
# 8      2400000.0         3          3  1428.0   Park Slope    sold
# ...          ...       ...        ...     ...          ...     ...
# 14727   765000.0         2          1   867.0      Wingate  listed
# 14728   630000.0         0          1  1492.0      Wingate  listed
# 14729   998000.0         4          2  1584.0      Wingate  listed
# 14730   830000.0         0          1   564.0      Wingate  listed
# 14732   629000.0         3          2  1470.0      Wingate  listed
#
# [12013 rows x 6 columns]

# %%
# prompt: Turn neighborhood and status features, string to numeric using labelencoder

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# Fit and transform the 'neighborhood' column
df['neighborhood'] = le.fit_transform(df['neighborhood'])

# Fit and transform the 'status' column
df['status'] = le.fit_transform(df['status'])

df
# Out:
# <ipython-input-7-a07785837d8c>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['neighborhood'] = le.fit_transform(df['neighborhood'])
# <ipython-input-7-a07785837d8c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['status'] = le.fit_transform(df['status'])
#            price  bedrooms  bathrooms    sqft  neighborhood  status
# 0      4100000.0         4          5  2940.0            32       1
# 4       908000.0         0          1  1066.0            32       1
# ...

# %%
# Because we only want the sold homes to account for this model, we eliminate the listed homes. 1 is sold and 0 is listed.
# Fit and transform the 'status' column
df['status'] = le.fit_transform(df['status'])

df = df[df['status'] != 0]
df
# Out:
# <ipython-input-8-671d853e7f6b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['status'] = le.fit_transform(df['status'])
#            price  bedrooms  bathrooms    sqft  neighborhood  status
# 0      4100000.0         4          5  2940.0            32       1
# 4       908000.0         0          1  1066.0            32       1
# 6      2600000.0         5          4  3600.0            32       1
# 7      4050000.0         4          4  3600.0            32       1
# 8      2400000.0         3          3  1428.0            32       1
# ...          ...       ...        ...     ...           ...     ...
# 14687   360000.0         1          1   700.0            41       1
# ...

# %%
# Eliminate data that has 1000 or less in price
# This is to prevent any unrealistic entries (e.g. human data entry error)

df = df[df['price'] > 1000]
df
# Out:
#            price  bedrooms  bathrooms    sqft  neighborhood  status
# 0      4100000.0         4          5  2940.0            32       1
# 4       908000.0         0          1  1066.0            32       1
# 6      2600000.0         5          4  3600.0            32       1
# 7      4050000.0         4          4  3600.0            32       1
# 8      2400000.0         3          3  1428.0            32       1
# ...          ...       ...        ...     ...           ...     ...
# 14687   360000.0         1          1   700.0            41       1
# 14688  1800000.0         8          3  1890.0            41       1
# 14689  1275000.0         5          3  3960.0            41       1
# 14690   450000.0         2          1   840.0            41       1
# 14692   625000.0         2          2   890.0            41       1
#
# [6561 rows x 6 columns]

# %%
#IF you ever wanted to see the entire dataset in Excel view at this point of  the model development, you can download the current version of dataset
#Convert the DataFrame to CSV and download
df.to_csv('processed_brooklyn_listings.csv', index=False)
files.download('processed_brooklyn_listings.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-8fe053a2d653> in <cell line: 0>()
#       2 #Convert the DataFrame to CSV and download
#       3 df.to_csv('processed_brooklyn_listings.csv', index=False)
# ----> 4 files.download('processed_brooklyn_listings.csv')
#
# NameError: name 'files' is not defined

# %%
# Let's split the dataset into x (bedrooms, sqft, neighboorhood and status) and y (price).

# Define features (x) and target (y)
x = df[['bedrooms', 'sqft', 'neighborhood', 'status']]
y = df['price']

# %%
# Let's do a regression analysis

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Split data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Initialize and train a linear regression model
model = LinearRegression()
model.fit(x_train, y_train)

# Make predictions on the test set
y_pred = model.predict(x_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 1361554607221.2625
# R-squared: 0.04483145079299822

# %% [markdown]
# MSE is too high and R2 is also too low, this means the dataset is lousy. The management/client must reconsider another step to the dataset (e.g. split the data per neighborhood, etc)

# %%
# Let's have user enter the data and get a price prediction.

def get_prediction():
    while True:
        try:
            bedrooms = int(input("Enter the number of bedrooms: "))
            if bedrooms < 0:
                print("Please enter a non-negative number of bedrooms.")
                continue
            sqft = int(input("Enter the square footage: "))
            if sqft <= 0 :
                print("Please enter a positive square footage.")
                continue
            neighborhood = input("Enter the neighborhood (use the numerical code from the original dataset): ")
            neighborhood = int(neighborhood)
            status = 1 # We only predict for sold houses in this model.

            # Create input array
            input_data = nm.array([[bedrooms, sqft, neighborhood, status]])

            # Make prediction
            predicted_price = model.predict(input_data)[0]

            print(f"Predicted price: ${predicted_price:.2f}")
            break  # Exit the loop if input is valid

        except ValueError:
            print("Invalid input. Please enter numeric values for bedrooms and sqft, and a valid numerical code for neighborhood.")
        except Exception as e:
          print(f"An error occurred: {e}")
          print("Please restart and enter the correct values.")
          break
while True:
    get_prediction()
    another_prediction = input("Do you want to predict another price? (yes/no): ")
    if another_prediction.lower() != 'yes':
        break
# Out:
# Enter the number of bedrooms: 16
# Enter the square footage: 90000
# Enter the neighborhood (use the numerical code from the original dataset): 32
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# Predicted price: $4366785.85
# Do you want to predict another price? (yes/no): no
